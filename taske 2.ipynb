# %%
            from langchain_ollama.llms import OllamaLLM
            from langchain.prompts import PromptTemplate
            from langchain.chains import LLMChain

            # 01 Initialize Ollama model
            ollama = OllamaLLM(model="llama3.2") 

            #  LangChain prompt 
            template = """
You are a senior software engineer.
=================================
Score the code quality from 1 to 10
================================
, optimize it as order a list, 
================================
write notes in your code,
================================
write documentation,
================================
write unit tests for the following code: '{text}'
"""
            prompt = PromptTemplate(input_variables=["text"], template=template)

            # 03 Creating an LLM chain with Ollama and the prompt template
            chain = LLMChain(llm=ollama, prompt=prompt)

            # 04 using model to handle text embedding and sentiment classification
            input_text ='''

 from contextlib import contextmanager
 
@contextmanager

 def my_context():

     print("Entering the context")

     try:

         yield  # This is where the block inside the 'with' statement runs

     finally:

         print("Exiting the context'''
 
            result = chain.run(input_text)
            print(f"Sentiment: {result}")
# Out:
# /var/folders/x6/kzmpq__n0ld4183mgxkld8s80000gn/T/ipykernel_10690/2735118791.py:15: LangChainDeprecationWarning: The class `LLMChain` was deprecated in LangChain 0.1.17 and will be removed in 1.0. Use :meth:`~RunnableSequence, e.g., `prompt | llm`` instead.
#   chain = LLMChain(llm=ollama, prompt=prompt)
# /var/folders/x6/kzmpq__n0ld4183mgxkld8s80000gn/T/ipykernel_10690/2735118791.py:36: LangChainDeprecationWarning: The method `Chain.run` was deprecated in langchain 0.1.0 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   result = chain.run(input_text)
# Sentiment: Score: 4/10
#
# Here are some suggestions for optimization, notes in code, and writing code docs:
#
# **Optimization:**
#
# 1. **Use a more Pythonic way to indicate that this function should be used with a `with` statement**: Instead of using the `@contextmanager` decorator, you can use the context manager syntax directly on the function definition.
#
# ```python
# from contextlib import contextmanager
#
# ...

# %%
from langchain_ollama.llms import OllamaLLM;print(Ollama(model='llama3.2')(prompets = input('what is your question: ')),end=' ')
# Out:
# {'text': 'Score: 6/10\n\nOptimization List:\n\n1.  **Consistent Naming Conventions**: The code uses both camelCase and underscore notation for variable names. It\'s recommended to stick to a single convention throughout the codebase.\n2.  **Docstrings**: There are no docstrings provided for functions or classes, making it difficult for others (and yourself) to understand their purpose.\n3.  **Type Hints**: The function `my_context` doesn\'t have any type hints, which can make it harder to understand its expected input and output types.\n4.  **Error Handling**: The code only prints messages when entering and exiting the context. It would be better to raise an exception or return a specific value to indicate failure.\n5.  **Magic Strings**: The string "Entering the context" and "Exiting the context" are hardcoded. Consider defining these as constants for easier maintenance.\n\nImproved Code:\n\n```python\n# my_context.py\n\nfrom typing import Any, ContextManager\nimport logging\n\n# De
# ...
